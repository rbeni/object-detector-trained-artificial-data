# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='TRUE'

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.13 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5938MiB)
# Setup complete ✅ (16 CPUs, 31.1 GB RAM, 162.1/456.4 GB disk)

# %%
from ultralytics import YOLO
import numpy as np
from IPython.display import display, Image

# %%
# Check pytorch is compiled with cuda support
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
Image(filename='../../data_v2/images/Image0005.png', height=500)

# %%
model = YOLO(f'./yolov8n.pt')
results = model.predict(source='../../data_v2/images/Image0005.png', save=True, conf=0.25)
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.13 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5938MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# Results saved to runs/detect/predict6

# %%
Image(filename='runs/detect/predict6/Image0005.png', height=500)

# %%
model.train(name='experiment-500n', data='./data.yaml', pretrained=True, model='yolov8n.pt', workers=4, epochs=300, imgsz=500, seed=42)
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.13 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5938MiB)
# ...

# %%
model = YOLO('runs/detect/experiment-500n/weights/best.pt')
results = model.predict(source='../../datasets/size500/test/images/Image0451.png', save=True, conf=0.25)
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.13 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5938MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# Results saved to runs/detect/predict7

# %%
Image(filename='./runs/detect/predict7/Image0451.png', height=500)

# %%
# model = YOLO('runs/detect/experiment-16/weights/best.pt')

# %%
results = model.predict(source='./real_images/pusb1.png', save=True, conf=0.25)
Image(filename='./runs/detect/predict7/pusb1.png', height=500)
# Out:
# Results saved to runs/detect/predict7

# %%
results = model.predict(source='./real_images/pusb2.png', save=True, conf=0.25)
Image(filename='./runs/detect/predict7/pusb2.png', height=500)
# Out:
# Results saved to runs/detect/predict7

# %%
results = model.predict(source='./real_images/pusb3.png', save=True, conf=0.25)
Image(filename='./runs/detect/predict7/pusb3.png', height=500)
# Out:
# Results saved to runs/detect/predict7

# %%
results = model.predict(source='./real_images/pusb4.png', save=True, conf=0.5)
Image(filename='./runs/detect/predict7/pusb4.png', height=500)
# Out:
# Results saved to runs/detect/predict7

# %%
results
# Out:
# [Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([2, 6])
#  dtype: torch.float32
#   + tensor([[409.00000,  87.00000, 500.00000, 176.00000,   0.86036,   0.00000],
#          [268.00000,  81.00000, 483.00000, 175.00000,   0.65835,   0.00000]], device='cuda:0')]

# %%
results = model.predict(source='./real_images/pusb5.png', save=True, conf=0.5)
Image(filename='./runs/detect/predict7/pusb5.png', height=500)
# Out:
# Results saved to runs/detect/predict7
